# %% [markdown]
# ### Dataset testing

# %%
import matplotlib.pyplot as plt
import data
import torch

# %%
data.main()
# Out:
# Loading train data from : ./data/... Done.
# Loading test data from : ./data/... Done.
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
## Exploring by hand:

data_folder = "./data/"
X_train, y_train, X_test, y_test = data.load_data(data_folder)
train = data.to_dataloader(X_train, y_train)
test = data.to_dataloader(X_test, y_test)
# Out:
# Loading train data from : ./data/... Done.
# Loading test data from : ./data/... Done.

# %%
### Basic information about dataset:
print("Lenght of training dataset:", len(train.dataset))
print()
print("Lenght of test dataset:", len(test.dataset))
# Out:
# Lenght of training dataset: 500
#
# Lenght of test dataset: 100

# %%
## Visualizing examples from the training dataset
img_index = 45

plt.imshow(train.dataset[img_index][0].permute(1,2,0))
plt.title("Original Image")
plt.show()
data.viz_sample(train.dataset[img_index][0], train.dataset[img_index][1], permute = True)
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
## Let's take a closer look at one joint target:
print("Max target value:", train.dataset[img_index][1][0].max())
plt.imshow(train.dataset[img_index][1][0])
plt.title("Visualizing one target")
plt.show()

torch.set_printoptions(threshold=10000)
print(train.dataset[img_index][1][0])
# Out:
# Max target value: tensor(0.2500)
# tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
# ...
